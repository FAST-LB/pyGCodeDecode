# %%
# %matplotlib widget
from pyGCodeDecode import gcode_interpreter

###Fictional Printer Preset
fictional_printer = {
    #general properties
    "nozzle_diam"   :   0.4,
    "filament_diam" :   1.75,
    
    #default settings
    "velocity"      :   35,
    "acceleration"  :   20,
    "jerk"          :   2,
    
    #axis max speeds
    "Vx"            :   60,
    "Vy"            :   60,
    "Vz"            :   40,
    "Ve"            :   25
    }

anisoprint_A4 = {
    #general properties
    "nozzle_diam"   :   0.4,
    "filament_diam" :   1.75,
    
    #default settings
    "velocity"      :   35,
    "acceleration"  :   1000,
    "jerk"          :   10,
    
    #axis max speeds
    "Vx"            :   180,
    "Vy"            :   180,
    "Vz"            :   30,
    "Ve"            :   33
    }

""" INITIAL POSITION:
    None        -> start from zero
    True        -> use first gcode G1 command as initial position
    [x,y,z,e]   -> non zero coordinates for initial position
"""
initial_position = None

new = gcode_interpreter.simulate(filename=r"test.gcode",printer=anisoprint_A4,initial_position=initial_position)
# Out:
# [##########] 100% of Planner Block Generation Done...
#  >> pyGCodeDecode extracted 1809 states from test.gcode and generated 1808 plannerblocks.
#
#             Estimated time to travel all states with provided printer settings is 126.87203618304746 seconds.

# %%
new.plot_2d_position(filename=False,show=True,colvar_spatial_resolution=0.1)
# Out:
# [##########] 100% of 2D Plot Lines Done...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
new.plot_vel(show=True,filename=False)
# Out:
# [##########] 100% of Velocity Plot Done...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
new.states
# Out:
# [<<< State Information line: 0 >>>
#   >>> Position
#  x: 0
#  y: 0
#  z: 0
#  e: 0
#   >>> Print Settings:
#  Jerk: 10
#  Printing Acceleration: 1000
#  Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
#  Printing speed: 35
#  Abs Extr: True,
#  <<< State Information line: 3 >>>
#   >>> Position
#  x: 0.0
#  y: 0.0
#  z: 0.2
#  e: 0.0
#   >>> Print Settings:
#  Jerk: 2.0
#  Printing Acceleration: 30.0
#  Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
#  Printing speed: 13.333333333333334
#  Abs Extr: True,
#  <<< State Information line: 4 >>>
#   >>> Position
#  x: 3.0
#  y: 0.0
#  z: 0.2
#  e: 4.0
#   >>> Print Settings:
#  Jerk: 2.0
#  Printing Acceleration: 30.0
#  Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
#  Printing speed: 13.333333333333334
#  Abs Extr: True,
#  <<< State Information line: 5 >>>
#   >>> Position
#  x: 3.0
#  y: 3.0
#  z: 0.2
#  e: 8.0
#   >>> Print Settings:
#  Jerk: 2.0
#  Printing Acceleration: 30.0
# ...

# %%
new.states[2].next_state
# Out:
# <<< State Information line: 5 >>>
#  >>> Position
# x: 3.0
# y: 3.0
# z: 0.2
# e: 8.0
#  >>> Print Settings:
# Jerk: 2.0
# Printing Acceleration: 30.0
# Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
# Printing speed: 13.333333333333334
# Abs Extr: True

# %%
new.states[3].prev_state
# Out:
# <<< State Information line: 4 >>>
#  >>> Position
# x: 3.0
# y: 0.0
# z: 0.2
# e: 4.0
#  >>> Print Settings:
# Jerk: 2.0
# Printing Acceleration: 30.0
# Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
# Printing speed: 13.333333333333334
# Abs Extr: True

# %%
new.plot_vel(filename=False,show=True,timesteps=2000)
# Out:
# [##########] 100% of Velocity Plot Done...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
