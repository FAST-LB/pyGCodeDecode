# %%
# %matplotlib widget
from pyGCodeDecode import gcode_interpreter
import matplotlib.pyplot as plt
import numpy as np
# ipympl can be install via pip: "pip install ipympl"

# %%
#PRINTER DEFINITION
anisoprint_A4 = {
    #general properties
    "nozzle_diam"   :   0.4,
    "filament_diam" :   1.75,
    
    #default settings
    "velocity"      :   35,
    "acceleration"  :   1000,
    "jerk"          :   10,
    
    #axis max speeds
    "Vx"            :   180,
    "Vy"            :   180,
    "Vz"            :   30,
    "Ve"            :   33
    }

prusa_mini = {
    #general properties
    "nozzle_diam"   :   0.4,
    "filament_diam" :   1.75,
    
    #default settings
    "velocity"      :   35,
    "acceleration"  :   1250,
    "jerk"          :   8,
    
    #axis max speeds
    "Vx"            :   180,
    "Vy"            :   180,
    "Vz"            :   12,
    "Ve"            :   80
    }

# %%
initial_position = True

aniso = gcode_interpreter.simulate(filename=r"drop.gcode",printer=anisoprint_A4,initial_position=initial_position)
#prusa = gcode_interpreter.simulate(filename=r"drop.gcode",printer=prusa_mini,initial_position=initial_position)
# Out:
# [##########] 100% of Planner Block Generation Done...
#  >> pyGCodeDecode extracted 146 states from drop.gcode and generated 139 plannerblocks.
#  Estimated time to travel all states with provided printer settings is 6.209802984901826 seconds.

# %%
aniso.plot_3d_position(show=True)
# Out:
# [##########] 100% of 3D Plot Done...
# 3D Plot saved as  trajectory_3D.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
aniso.plot_vel(axis=("x","y"),show_plannerblocks=True,filename="velplot_aniso.png")
#prusa.plot_vel(axis=("x","y"),show_plannerblocks=True,filename="velplot_prusa.png")
# Out:
# [##########] 100% of Velocity Plot Done...

# %%
aniso.plot_2d_position(colvar="Velocity",colvar_spatial_resolution=0.1,show=True)
# Out:
# [##########] 100% of 2D Plot Lines Done...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
