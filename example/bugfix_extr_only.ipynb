# %%
# %matplotlib widget
from pyGCodeDecode import gcode_interpreter

###Fictional Printer Preset
fictional_printer = {
    #general properties
    "nozzle_diam"   :   0.4,
    "filament_diam" :   1.75,
    
    #default settings
    "velocity"      :   35,
    "acceleration"  :   20,
    "jerk"          :   2,
    
    #axis max speeds
    "Vx"            :   60,
    "Vy"            :   60,
    "Vz"            :   40,
    "Ve"            :   25
    }

anisoprint_A4 = {
    #general properties
    "nozzle_diam"   :   0.4,
    "filament_diam" :   1.75,
    
    #default settings
    "velocity"      :   35,
    "acceleration"  :   1000,
    "jerk"          :   10,
    
    #axis max speeds
    "Vx"            :   180,
    "Vy"            :   180,
    "Vz"            :   30,
    "Ve"            :   33
    }

""" INITIAL POSITION:
    None        -> start from zero
    True        -> use first gcode G1 command as initial position
    [x,y,z,e]   -> non zero coordinates for initial position
"""
initial_position = None

new = gcode_interpreter.simulate(filename=r"test.gcode",printer=anisoprint_A4,initial_position=initial_position)
# Out:
#  planner_block/connect_state/travel_direction:  [10.  0.  0.  0.] 0.0
#
#  planner_block/connect_state/distance:  10.0
#
#  A: None B: <<< State Information line: 0 >>>
#  >>> Position
# x: 0
# y: 0
# z: 0
# e: 0
#  >>> Print Settings:
# Jerk: 10
# Printing Acceleration: 1000
# Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
# Printing speed: 35
# Abs Extr: True
#
#
#  A vel: Velocity: [Vx:0, Vy:0, Vz:0, Ve:0] B vel: Velocity: [Vx:35.0, Vy:0.0, Vz:0.0, Ve:0.0] JD vel: 0
# planner_block/init/direction:  None
# VALID:  False
# #########Invalid Planner Block##########
# [##--------] 25.0% of Planner Block Generation
#  planner_block/connect_state/travel_direction:  [10.  0.  0.  0.] 0.0
#
#  planner_block/connect_state/distance:  10.0
#
#  A: <<< State Information line: 0 >>>
#  >>> Position
# x: 0
# y: 0
# z: 0
# e: 0
#  >>> Print Settings:
# Jerk: 10
# Printing Acceleration: 1000
# Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
# Printing speed: 35
# Abs Extr: True
#  B: <<< State Information line: 1 >>>
#  >>> Position
# x: 10.0
# y: 0
# z: 0
# e: 0
#  >>> Print Settings:
# Jerk: 10
# Printing Acceleration: 1000
# Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
# Printing speed: 35
# Abs Extr: True
#
#
#  A vel: Velocity: [Vx:35.0, Vy:0.0, Vz:0.0, Ve:0.0] B vel: Velocity: [Vx:0, Vy:0, Vz:0, Ve:0] JD vel: 0
# planner_block/init/direction:  [1. 0. 0. 0.]
# VALID:  True
# planner_block/movemaker2/v_begin:  0.0
# planner_block/movemaker2/distance:  10.0
# TRAPEZ ONLY EXTRUSION:  False
# ----------Trapez Planner Block----------
# [#####-----] 50.0% of Planner Block Generation
#  planner_block/connect_state/travel_direction:  [-10.   0.   0.  10.] 10.0
#
#  planner_block/connect_state/distance:  10.0
#
#  planner_block/connect_state/travel_direction:  [10.  0.  0.  0.] 0.0
#
#  planner_block/connect_state/distance:  10.0
#
#  A: <<< State Information line: 4 >>>
#  >>> Position
# x: 10.0
# y: 0
# z: 0
# e: 0
#  >>> Print Settings:
# Jerk: 10
# Printing Acceleration: 1000
# Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
# Printing speed: 35
# Abs Extr: True
#  B: <<< State Information line: 5 >>>
#  >>> Position
# x: 0.0
# y: 0.0
# z: 0.0
# e: 10.0
#  >>> Print Settings:
# Jerk: 10
# Printing Acceleration: 1000
# Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
# Printing speed: 35
# Abs Extr: True
#
#
#  A vel: Velocity: [Vx:-35.0, Vy:0.0, Vz:0.0, Ve:35.0] B vel: Velocity: [Vx:35.0, Vy:0.0, Vz:0.0, Ve:0.0] JD vel: 0
# planner_block/init/direction:  [-0.70710678  0.          0.          0.70710678]
# VALID:  True
# planner_block/movemaker2/v_begin:  0.0
# planner_block/movemaker2/distance:  10.0
# TRAPEZ ONLY EXTRUSION:  False
# ----------Trapez Planner Block----------
# [########--] 75.0% of Planner Block Generation
#  planner_block/connect_state/travel_direction:  [10.  0.  0.  0.] 0.0
#
#  planner_block/connect_state/distance:  10.0
#
#  A: <<< State Information line: 5 >>>
#  >>> Position
# x: 0.0
# y: 0.0
# z: 0.0
# e: 10.0
#  >>> Print Settings:
# Jerk: 10
# Printing Acceleration: 1000
# Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
# Printing speed: 35
# Abs Extr: True
#  B: <<< State Information line: 6 >>>
#  >>> Position
# x: 10.0
# y: 0.0
# z: 0.0
# e: 10.0
#  >>> Print Settings:
# Jerk: 10
# Printing Acceleration: 1000
# Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
# Printing speed: 35
# Abs Extr: True
#
#
#  A vel: Velocity: [Vx:35.0, Vy:0.0, Vz:0.0, Ve:0.0] B vel: Velocity: [Vx:0, Vy:0, Vz:0, Ve:0] JD vel: 0
# planner_block/init/direction:  [1. 0. 0. 0.]
# VALID:  True
# planner_block/movemaker2/v_begin:  0.0
# planner_block/movemaker2/distance:  10.0
# TRAPEZ ONLY EXTRUSION:  False
# ----------Trapez Planner Block----------
# [##########] 100% of Planner Block Generation Done...
#  >> pyGCodeDecode extracted 4 states from test.gcode and generated 3 plannerblocks.
#  Estimated time to travel all states with provided printer settings is 1.0659921145663973 seconds.

# %%
new.plot_vel(filename=False,show=True,timesteps=2000)
# Out:
# [##########] 100% of Velocity Plot Done...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
new.states
# Out:
# [<<< State Information line: 0 >>>
#   >>> Position
#  x: 0
#  y: 0
#  z: 0
#  e: 0
#   >>> Print Settings:
#  Jerk: 10
#  Printing Acceleration: 1000
#  Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
#  Printing speed: 35
#  Abs Extr: True,
#  <<< State Information line: 1 >>>
#   >>> Position
#  x: 10.0
#  y: 0
#  z: 0
#  e: 0
#   >>> Print Settings:
#  Jerk: 10
#  Printing Acceleration: 1000
#  Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
#  Printing speed: 35
#  Abs Extr: True,
#  <<< State Information line: 5 >>>
#   >>> Position
#  x: 0.0
#  y: 0.0
#  z: 0.0
#  e: 10.0
#   >>> Print Settings:
#  Jerk: 10
#  Printing Acceleration: 1000
#  Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
#  Printing speed: 35
#  Abs Extr: True,
#  <<< State Information line: 6 >>>
#   >>> Position
#  x: 10.0
#  y: 0.0
#  z: 0.0
#  e: 10.0
#   >>> Print Settings:
#  Jerk: 10
#  Printing Acceleration: 1000
#  Maximum Axis Speeds: [Vx:180, Vy:180, Vz:30, Ve:33]
#  Printing speed: 35
#  Abs Extr: True]

# %%
new.blocklist[3].state_B
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15796\412975510.py in <module>
# ----> 1 new.blocklist[3].state_B
#
# IndexError: list index out of range
